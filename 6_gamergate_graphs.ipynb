# %%
# %matplotlib inline

from graphs import *
import os

# %%
input_folder = "output/mallet"
output_folder = "output"
date_format = "%Y-%m-%d.txt"
title = "Gamergate Tweets"

# %%
dates, topics, names = import_doc_topics(input_folder, date_format)

# %%
graph_dendrogram(
    data=topics,
    dates=dates,
    title=title,
    output_file=f"{output_folder}/cluster.png"
)

# %%
output = f"{output_folder}/topics"
os.makedirs(output, exist_ok=True)
graph_topics(
    data=topics,
    dates=dates,
    output_folder=output
)

# %%
#generate topics
all_words = get_word_frequencies(input_folder)
stopwords = {"gamergate", "twitter_link", "newline", "notyourshield"}

# %%
to_graph = [5, 9, 12]
graph_all_topics(
    data=topics,
    dates=dates,
    title="out-time",
    topics=to_graph,
    output_file=f"{output_folder}/topics-out-time.png"
)
keys_by_order(
    words_raw=all_words,
    topics=to_graph,
    stopwords=stopwords,
    n_keys=10,
    output_file=f"{output_folder}/topics-out-time-table.png"
)

# %%
to_graph = [0,1,2,3,4,6,7,8,10,11,13,14,15]
graph_all_topics(
    data=topics,
    dates=dates,
    title="in-time",
    topics=to_graph,
    output_file=f"{output_folder}/topics-in-time.png"
)

keys_by_order(
    words_raw=all_words,
    topics=to_graph,
    stopwords=stopwords,
    n_keys=10,
    output_file=f"{output_folder}/topics-in-time-table.png"
)

# %%
# Let's generate example strings. These are strings of words that are all the same topic.
output = f"{output_folder}/examples"
os.makedirs(output, exist_ok=True)

examples = examples(
    length=5,
    input_folder=input_folder,
    output_folder=output,
)

# %%
output = f"{output_folder}/keys"
os.makedirs(output, exist_ok=True)

# Generate all topic keyword graphs.
create_token_hist(
    data_raw=all_words,
    num_keys=40,
    output_folder=output,
    stopwords=stopwords
)

keys_csv(
    words_raw=all_words,
    output_file=f"{output_folder}/keys.csv",
    stopwords=stopwords,

)

# %%
output = f"{output_folder}/documents"
os.makedirs(output, exist_ok=True)

graph_documents(
    data=topics,
    output_folder=output,
    names=names
)
# Out:
# /home/ryan/local/ggorigins/graphs.py:212: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(1, 1, figsize=(10,5))
